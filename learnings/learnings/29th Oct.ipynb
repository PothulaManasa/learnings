# %% [markdown]
# Question: Task: Ask user to enter list of words
# Note: minimum 10 words should accept
#
# Your program should print following in a TEXT FILE
#
# 👉 Highest length of the word in that list
# 👉 Lowest length of the word
# 👉 Words count
# 👉 Sort list: ascending order and descending order.
# 👉  Check any word is repeating in the list. If repeated then count.
# 👉 Print each word along with character count
# 👉 Print each word along with vowels count
#
# Before printing each functionality should have a HORIZONTAL line along with some description ( which functionality you developed).
#
# Use functions and files concept.
# Don't show any output here.
# Need Out put as
# """
#  something.txt file generated successfully. File locted here -C:\\User\something.txt

# %%
import sys
filepath = 'check1.txt'
def operations():

    opt=int(input())

    if opt==1:
        highlength()
    elif opt==2:
        lowlength()
    elif opt==3:
        count()
    elif opt==4:
        ascendingOrder()
    elif opt==5:
        descendingOrder()
    elif opt==6:
        duplicate()
    elif opt==7:
        countOfWords()
    elif opt==8:
        vowelsCount()
    elif opt==9:
        dataInFile()
    elif opt==0:
        sys.exit("Thank You. Your file location is Desktop/problemsolvingprogramming-june-2019/check1.txt")
    else:
        sys.exit("Select valid operation")


print("Please enter more than 10 words")
s=input()
l1=s.split()

if len(l1)<10:
    sys.exit("Please enter minimum 10 words")
    
l2=[]
wordCount={}
for i in l1:
    l2.append(len(i))
    wordCount[i]=len(i)
#print(wordCount)
# print(l2)
#To print words along with the count
unique={}
for i in l1:
    if i not in unique:
        unique[i]=1
    else:
        unique[i]+=1
#print(unique)
#Calculate duplicate number of duplicate words
l3=[]
for word in unique.items():
    if word[1]>1:
        l3.append(word)

#To count the number of Vowels
vowels={}
for i in l1:
    l=list(i.strip())
#     print(l)
    counter=0
    for j in i:
        if j=='a' or j=='e' or j=='i' or j=='o' or j=='u':
            counter+=1
#         print(counter)
    if i not in vowels:
        vowels[i]=counter
#print(vowels)

    
 #Highest length of the word in that list
def highlength():
    l=[]
    
    for length in wordCount.items():
        if length[1]==(max(l2)):
            l.append(length[0])
    with open(filepath, 'a') as f:
        line='Words with maximum length are'+str(l)+'\n'+'Maximum length of given words is '+str(max(l2))+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

#Lowest length of the word
def lowlength():
    l4=[]
    for length in wordCount.items():
            if length[1]==(min(l2)):
                l4.append(length[0])
    with open(filepath, 'a') as f:
        line='Minimum length of given words are '+str(min(l2))+'\n'+'Words with minimum length is '+str(l4)+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()
                

#Words count
def count():
    with open(filepath, 'a') as f:
        line='Count of words is '+str(len(l1))+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

#Sort list: ascending order and descending order.
def ascendingOrder():
    l1.sort()
    with open(filepath, 'a') as f:
        line='Ascending order of the list is '+str(l1)+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

def descendingOrder():  
    l1.sort(reverse=True)
    with open(filepath, 'a') as f:
        line='Descending order of the list is '+str(l1)+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

#Check any word is repeating in the list. If repeated then count.
def duplicate():
    with open(filepath, 'a') as f:
        line='repeating words are '+str(l3)+'\n'+'number of words repeated more than once are '+str(len(l3))+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

#Print each word along with character count
def countOfWords():
    with open(filepath, 'a') as f:
        line='Words with their count is '+str(wordCount)+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()

#Print each word along with vowels count
def vowelsCount():
    with open(filepath, 'a') as f:
        line='Vowels count in each word '+str(vowels)+'\n'
        f.write(line)
    print("File created and data inserted successfully")
    operations()
def dataInFile():
    with open(filepath, 'r') as f:
        data=f.read()
        print(data)
    operations()
print("select the operation you want to perform")
print("enter 1 for highest lenth")
print("enter 2 for lowest lenth")
print("enter 3 for number of words")
print("enter 4 for ascending order")
print("enter 5 for descending order")
print("enter 6 to know the duplicate words")
print("enter 7 for words count")
print("enter 8 for vowels count")
print("enter 9 to check the data in the file")
print("enter 0 to exit")

operations()
# manasa alekhya tilak babu raviteja bharath bhavani indira nagasai lavanya manasa
# Out:
# Please enter more than 10 words
# manasa alekhya tilak babu raviteja bharath bhavani indira nagasai lavanya
# select the operation you want to perform
# enter 1 for highest lenth
# enter 2 for lowest lenth
# enter 3 for number of words
# enter 4 for ascending order
# enter 5 for descending order
# enter 6 to know the duplicate words
# enter 7 for words count
# enter 8 for vowels count
# enter 9 to check the data in the file
# enter 0 to exit
# 1
# File created and data inserted successfully
# 2
# File created and data inserted successfully
# 3
# File created and data inserted successfully
# 4
# File created and data inserted successfully
# 5
# File created and data inserted successfully
# 6
# File created and data inserted successfully
# 9
# Words with maximum length are['raviteja']
# Maximum length of given words is 8
# Minimum length of given words are 4
# Words with minimum length is ['babu']
# Count of words is 10
# ...

# %% [markdown]
# Task of the day:
# What is Map, Reduce and Filter? Write an example program for those.
