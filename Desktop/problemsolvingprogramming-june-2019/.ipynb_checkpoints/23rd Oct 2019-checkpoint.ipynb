# %% [markdown]
# Task: Ask user to enter list of words
# Note: minimum 10 words should accept
#
# Your program should print following
#
# 👉 Highest length of the word in that list
# 👉 Lowest length of the word
# 👉 Words count
# 👉 Sort list: ascending order and descending order.
# 👉  Check any word is repeating in the list. If repeated then count.
# 👉 Print each word along with character count
# 👉 Print each word along with vowels count
#
# Before printing each functionality should have a HORIZONTAL line along with some description ( which functionality you developed).
#
# Use functions concept only....

# %%
import sys

def operations():

    opt=int(input())

    if opt==1:
        highlength()
    elif opt==2:
        lowlength()
    elif opt==3:
        count()
    elif opt==4:
        ascendingOrder()
    elif opt==5:
        descendingOrder()
    elif opt==6:
        duplicate()
    elif opt==7:
        countOfWords()
    elif opt==8:
        vowelsCount()
    elif opt==0:
        sys.exit("Thank You")
    else:
        sys.exit("Select valid operation")


print("Please enter more than 10 words")
s=input()
l1=s.split()

if len(l1)<10:
    sys.exit("Please enter minimum 10 words")
    
l2=[]
wordCount={}
for i in l1:
    l2.append(len(i))
    wordCount[i]=len(i)
#print(wordCount)
# print(l2)
#To print words along with the count
unique={}
for i in l1:
    if i not in unique:
        unique[i]=1
    else:
        unique[i]+=1
#print(unique)
#Calculate duplicate number of duplicate words
l3=[]
for word in unique.items():
    if word[1]>1:
        l3.append(word)

#To count the number of Vowels
vowels={}
for i in l1:
    l=list(i.strip())
#     print(l)
    counter=0
    for j in i:
        if j=='a' or j=='e' or j=='i' or j=='o' or j=='u':
            counter+=1
#         print(counter)
    if i not in vowels:
        vowels[i]=counter
#print(vowels)

    
 #Highest length of the word in that list
def highlength():
    l=[]
    print("Maximum length of given words is",max(l2))
    for length in wordCount.items():
        if length[1]==(max(l2)):
            l.append(length[0])
    print("Words with maximum length are", l)
    operations()

#Lowest length of the word
def lowlength():
    l4=[]
    print("Minimum length of given words are",min(l2))
    for length in wordCount.items():
            if length[1]==(min(l2)):
                l4.append(length[0])
    print("Words with minimum length is",l4)
    operations()
                

#Words count
def count():
    print("Count of words is", len(l1))
    operations()

#Sort list: ascending order and descending order.
def ascendingOrder():
    l1.sort()
    print("Ascending order of the list is", l1)
    operations()

def descendingOrder():  
    l1.sort(reverse=True)
    print("Descending order of the list is ", l1)
    operations()

#Check any word is repeating in the list. If repeated then count.
def duplicate():
    print("repeating words are", l3)
    print("number of words repeated more than once are ", len(l3))
    operations()

#Print each word along with character count
def countOfWords():
    print("Words with their count is", wordCount)
    operations()

#Print each word along with vowels count
def vowelsCount():
    print("Vowels count in each word ", vowels)
    operations()
print("select the operation you want to perform")
print("enter 1 for highest lenth")
print("enter 2 for lowest lenth")
print("enter 3 for number of words")
print("enter 4 for ascending order")
print("enter 5 for descending order")
print("enter 6 to know the duplicate words")
print("enter 7 for words count")
print("enter 8 for vowels count")
print("enter 0 to exit")

operations()
# Out:
# Please enter more than 10 words
# manasa alekhya raviteja tilak babu bhavani bharath indira akhil manasa
# select the operation you want to perform
# enter 1 for highest lenth
# enter 2 for lowest lenth
# enter 3 for number of words
# enter 4 for ascending order
# enter 5 for descending order
# enter 6 to know the duplicate words
# enter 7 for words count
# enter 8 for vowels count
# enter 0 to exit
# 1
# Maximum length of given words is 8
# Words with maximum length are ['raviteja']
# 2
# Minimum length of given words are 4
# Words with minimum length is ['babu']
# 3
# Count of words is 10
# 4
# Ascending order of the list is ['akhil', 'alekhya', 'babu', 'bharath', 'bhavani', 'indira', 'manasa', 'manasa', 'raviteja', 'tilak']
# 5
# Descending order of the list is  ['tilak', 'raviteja', 'manasa', 'manasa', 'indira', 'bhavani', 'bharath', 'babu', 'alekhya', 'akhil']
# 6
# repeating words are [('manasa', 2)]
# number of words repeated more than once are  1
# 7
# ...

# %%
def operation(opt):
    if opt==1:
        highlength()
    elif opt==2:
        lowlength()
    elif opt==3:
        count()
    elif opt==4:
        ascendingOrder()
    elif opt==5:
        descendingOrder()
    elif opt==6:
        unique()
    elif opt==7:
        wordCount()
    elif opt==8:
        vowelsCount()
    

#Highest length of the word in that list
def highlength():
    l=[]
    print("Maximum length of given words is",max(l2))
    for length in wordCount.items():
            if length[1]==(max(l2)):
                l.append(length[0])
                print("Words with maximum length is", l)
                return l

#Lowest length of the word
def lowlength():
    l=[]
    print("Minimum length of given words is",min(l2))
    for length in wordCount.items():
            if length[1]==(min(l2)):
                l.append(length[0])
                print("Words with minimum length is",l)
                return l

#Words count
def count():
    print("Count of words is", len(l1))
    return len(l1)

#Sort list: ascending order and descending order.
def ascendingOrder():
    l1.sort()
    print("Ascending order of the list is", l1)
    return l1

def descendingOrder():  
    l1.sort(reverse=True)
    print("Descending order of the list is ", l1)
    return l1

#Check any word is repeating in the list. If repeated then count.
def unique():
    print("repeating words are", l3)
    print("number of words repeated more than once are ", len(l3))
    return l3

#Print each word along with character count
def wordCount():
    print("Words with their count is", wordCount)
    return wordCount

#Print each word along with vowels count
def vowelsCount():
    print("Vowels count in each word ", vowels)
    return vowels
s=input()
words(s)
# Out:
# manasa alekhya raviteja tilak manasa manasa alekhya raviteja tilak manasa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-549a180a5bd3> in <module>
#      70     return vowels
#      71 s=input()
# ---> 72 words(s)
#
# NameError: name 'words' is not defined

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea320d2ace30> in <module>
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l4=[]
print("Maximum length of given words is",max(l2))
for length in wordCount.items():
        if length[1]==(max(l2)):
            l4.append(length[0])
            print("Words with maximum length are", l4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ceaab5aaba02> in <module>
#       1 l4=[]
# ----> 2 print("Maximum length of given words is",max(l2))
#       3 for length in wordCount.items():
#       4         if length[1]==(max(l2)):
#       5             l4.append(length[0])
#
# NameError: name 'l2' is not defined

# %%
s=input()
l1=s.split()
l2=[]
wordCount={}
for i in l1:
    l2.append(len(i))
    wordCount[i]=len(i)
#print(wordCount)
#To print words along with the count
unique={}
for i in l1:
    if i not in unique:
        unique[i]=1
    else:
        unique[i]+=1
#print(unique)
#Calculate duplicate number of duplicate words
l3=[]
for word in unique.items():
    if word[1]>1:
        l3.append(word)

#To count the number of Vowels
vowels={}
for i in l1:
    l=list(i.strip())
#     print(l)
    counter=0
    for j in i:
        if j=='a' or j=='e' or j=='i' or j=='o' or j=='u':
            counter+=1
#         print(counter)
    if i not in vowels:
        vowels[i]=counter
#print(vowels)

#Highest length of the word in that list
l4=[]
print("Maximum length of given words is",max(l2))
for length in wordCount.items():
        if length[1]==(max(l2)):
            l4.append(length[0])
            print("Words with maximum length are", l4)


#Lowest length of the word
l5=[]
print("Minimum length of given words is",min(l2))
for length in wordCount.items():
        if length[1]==(min(l2)):
            l5.append(length[0])
            print("Words with minimum length are",l5)

#Words count
print("Count of words is", len(l1))

#Sort list: ascending order and descending order.
l1.sort()
print("Ascending order of the list is", l1)

l1.sort(reverse=True)
print("Descending order of the list is ", l1)

#Check any word is repeating in the list. If repeated then count.
print("repeating words are", l3)
print("number of words repeated more than once are ", len(l3))

#Print each word along with character count
print("Words with their count is", wordCount)

#Print each word along with vowels count
print("Vowels count in each word ", vowels)
# Out:
# manasa alekhya raviteja tilak manasa
# Maximum length of given words is 8
# Words with maximum length are ['raviteja']
# Minimum length of given words is 5
# Words with minimum length are ['tilak']
# Count of words is 5
# Ascending order of the list is ['alekhya', 'manasa', 'manasa', 'raviteja', 'tilak']
# Descending order of the list is  ['tilak', 'raviteja', 'manasa', 'manasa', 'alekhya']
# repeating words are [('manasa', 2)]
# number of words repeated more than once are  1
# Words with their count is {'manasa': 6, 'alekhya': 7, 'raviteja': 8, 'tilak': 5}
# Vowels count in each word  {'manasa': 3, 'alekhya': 3, 'raviteja': 4, 'tilak': 2}
